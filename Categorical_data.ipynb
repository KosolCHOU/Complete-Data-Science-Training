# %% [markdown]
# <a href="https://colab.research.google.com/github/KosolCHOU/Complete-Data-Science-Training/blob/main/Categorical_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of cluster anaysis

# %% [markdown]
# ## Import relevent libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv("3.01.+Country+clusters.csv")
data
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %% [markdown]
# ## Map the data

# %%
data_mapped = data.copy()
data_mapped["Language"] = data_mapped['Language'].map({"English":0,"French":1,"German":2})
data_mapped
# Out:
#      Country  Latitude  Longitude  Language
# 0        USA     44.97    -103.77         0
# 1     Canada     62.40     -96.80         0
# 2     France     46.75       2.40         1
# 3         UK     54.01      -2.53         0
# 4    Germany     51.15      10.40         2
# 5  Australia    -25.45     133.11         0

# %% [markdown]
# ## Select the features

# %%
x = data_mapped.iloc[:, 1:4]
x
# Out:
#    Latitude  Longitude  Language
# 0     44.97    -103.77         0
# 1     62.40     -96.80         0
# 2     46.75       2.40         1
# 3     54.01      -2.53         0
# 4     51.15      10.40         2
# 5    -25.45     133.11         0

# %% [markdown]
# ## Clustering

# %%
kmeans = KMeans(2)

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# ## Clustering results

# %%
indentified_clusters = kmeans.fit_predict(x)
indentified_clusters
# Out:
# array([0, 0, 0, 0, 0, 1], dtype=int32)

# %%
data_with_clusters = data_mapped.copy()
data_with_clusters["Cluster"] = indentified_clusters
data_with_clusters
# Out:
#      Country  Latitude  Longitude  Language  Cluster
# 0        USA     44.97    -103.77         0        0
# 1     Canada     62.40     -96.80         0        0
# 2     France     46.75       2.40         1        0
# 3         UK     54.01      -2.53         0        0
# 4    Germany     51.15      10.40         2        0
# 5  Australia    -25.45     133.11         0        1

# %%
plt.scatter(data_with_clusters["Longitude"], data_with_clusters["Latitude"], c=data_with_clusters["Cluster"], cmap="rainbow")
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()
